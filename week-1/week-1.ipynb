# %% [markdown]
# # WEEK-1 (13.12.2023)
#
# ## print() Fonksiyonu Kullanım Biçimleri

# %%
print("hello")
print("hello", "world")
print("hello", "world", sep="-")
print("hello", "world", end=". ")
print("hello", "yaget", end=". ")
# Out:
# hello
# hello world
# hello-world
# hello world. hello yaget.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### print() Fonksiyonu Format Kullanımı

# %%
isim = "Yavuz Selim"
print("Hoşgeldin {}!".format(isim))

isim = "Ahmet Berk"
print("Hoşgeldin {0}!".format(isim))

isim = "Mahmut Tuncer"
print(f"Hoşgeldin {isim}!")
# Out:
# Hoşgeldin Yavuz Selim!
# Hoşgeldin Ahmet Berk!
# Hoşgeldin Mahmut Tuncer!

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ## input() Fonksiyonu Kullanım Biçimleri

# %%
isim = input("Lütfen isminizi girin: ")
# isim olarak Fatih girildi!

print(f"Hoşgeldin {isim}!")
print("Hoşgeldin " + isim + "!")
print("Hoşgeldin {}".format(isim), end="!")
# Out:
# Hoşgeldin Fatih!
# Hoşgeldin Fatih!
# Hoşgeldin Fatih!

# %%
sayi1 = int(input("1. Sayıyı girin: "))
sayi2 = int(input("2. Sayıyı girin: "))
# sayi1 = 2
# sayi2 = 3

print(sayi1 + sayi2)
# Out:
# 5

# %%
sayi1 = input("1. Sayıyı girin: ")
sayi2 = input("2. Sayıyı girin: ")
# sayi1 = 9
# sayi2 = 23
 
print(int(sayi1) + int(sayi2))
# Out:
# 32

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ## Python'da bir değişkenin veri tipini öğrenmek için type() fonksiyonu kullanılır.

# %%
x = 5
print(type(x))
y = 5.1
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ## Veri Tipleri
#
# ### Tam Sayılar (int)
# a = 5
# ### Ondalıklı Sayılar (float)
# b = 3.0

# %%
a = 5   # int
b = 3.0 # float

c = a + b
d = a - b
e = a * b
f = a / b

print(c) 
print(type(c))

print(d) 
print(type(d))

print(e) 
print(type(e))

print(f) 
print(type(f))
# Out:
# 8.0
# <class 'float'>
# 2.0
# <class 'float'>
# 15.0
# <class 'float'>
# 1.6666666666666667
# <class 'float'>

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### Karakter Dizileri (str)

# %%
isim = "Fatih"

print(isim)
print(type(isim))
# Out:
# Fatih
# <class 'str'>

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### Liste (list)
#
# #### Liste içerisindeki değerlere erişim adımları. İndexler 0'dan başlar.

# %%
liste = [1,2,3,4,5,6,"yedi"]

# listenin 0. indexini yazdırma
print("0. indexteki rakam = ", liste[0])

# listenin 5. indexini yazdırma
print("5. indexteki rakam = ", liste[5])

# listedeki 3 değerinin indexini bulma
print("3 değeri {}. indexte".format(liste.index(3)))
# Out:
# 0. indexteki rakam =  1
# 5. indexteki rakam =  6
# 3 değeri 2. indexte

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# #### Liste içerisine yeni bir değer ekleme ve çıkarma

# %%
liste = [1,2,3,4,5,6,"yedi"]

liste.append("yeni deger") # listenin sonuna ekler
print(liste)
# Out:
# [1, 2, 3, 4, 5, 6, 'yedi', 'yeni deger']

# %%
liste = [1,2,3,4,5,6,"yedi"]

liste.insert(1, "yeni deger") # listenin 1. indexine ekler
print(liste)
# Out:
# [1, 'yeni deger', 2, 3, 4, 5, 6, 'yedi']

# %%
liste = [1,2,3,4,5,6,"yedi",999]

liste.remove(999) # listenin içerisinde 999 değerini bulur ve siler
print(liste)
# Out:
# [1, 2, 3, 4, 5, 6, 'yedi']

# %%
liste = [1,2,3,4,5,6,"yedi"]

liste.pop(3) # listenin 3. indexini siler
print(liste)
# Out:
# [1, 2, 3, 5, 6, 'yedi']

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# #### Liste içerisinde bir değeri değiştirme

# %%
liste = [1,2,3,4,5,6,"yedi"]

liste[1] = "yeni deger" # listenin 1. indexinin değerini "yeni deger" yapar
print(liste)
# Out:
# [1, 'yeni deger', 3, 4, 5, 6, 'yedi']

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### Sözlük (dict)

# %%
sozluk = { "isim": "Fatih", "soyisim": "ZOR" }

print(sozluk["soyisim"])

print(sozluk.get("yas", "Yaş Yok!")) # istenilen değeri sözlükte bulamazsa default("Yaş Yok!") değeri döner
# Out:
# ZOR
# Yaş Yok!

# %%
sozluk = { "isim": "Fatih", "soyisim": "ZOR" }

sozluk["isim"] = "Mahmut"
print(sozluk["isim"])
# Out:
# Mahmut

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### Kümeler (set)

# %%
kume = {1,2,3,4,3}

print(kume)
# Out:
# {1, 2, 3, 4}

# %%
kume = {1,2,3,4,3}

kume.add(5)
print(kume)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### Demetler (tuple)

# %%
demet = (1,2,3,"dört")

print(demet[2])
# Out:
# 3

# %%
demet = (1,2,3,"dört")

demet[2] = 5 # Hata verir çünkü immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Fatih\Documents\GitKraken\python-egitimi\week-1\week-1.ipynb Cell 32 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Fatih/Documents/GitKraken/python-egitimi/week-1/week-1.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> demet = (1,2,3,"dört")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Fatih/Documents/GitKraken/python-egitimi/week-1/week-1.ipynb#X46sZmlsZQ%3D%3D?line=2'>3</a> demet[2] = 5 # Hata verir
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### Anlatılan tüm veri tipleri

# %%
integer_vt = 1
float_vt = 1.1
string_vt = "1"
list_vt = [1, 1.1, "1"]
tuple_vt = (1, 1.1, "1")
set_vt = {1, 1.1, "1"}
dictionary_vt = {"integer_vt_in_dict": 1, 
                 "float_vt_in_dict": 1.1, 
                 "string_vt_in_dict": "1", 
                 "list_vt_in_dict": [1,2,3], 
                 "tuple_vt_in_dict": (1,2,3),
                 "set_vt_in_dict": {1, 2, 3}
                }

print("Sözlüğün içindeki liste: ", dictionary_vt["list_vt_in_dict"])
print("Sözlüğün içindeki listenin 2. indexi: ", dictionary_vt["list_vt_in_dict"][2])

dictionary_vt["list_vt_in_dict"].insert(3, 999)
print("Sözlüğün içindeki listenin 3. indexine 999 eklendi: ", dictionary_vt["list_vt_in_dict"])
# Out:
# Sözlüğün içindeki liste:  [1, 2, 3]
# Sözlüğün içindeki listenin 2. indexi:  3
# Sözlüğün içindeki listenin 3. indexine 999 eklendi:  [1, 2, 3, 999]

# %% [markdown]
# ## Koşullu Durumlar

# %%
a = 1
b = 4
c = 3

if a>b:
    print("a buyuk")
elif b>c:
    print("b buyuk")
else:
    print("c buyuk")
# Out:
# b buyuk

# %%
# tüm if'leri sırayla dener

a = 1
b = 4
c = 3

if a>b:
    print("a buyuk")
elif b>c:
    print("b buyuk")
else:
    print("c buyuk")
    
if a>b:
    print("a buyuk")
if b>c:
    print("b buyuk")
if c>a:
    print("c buyuk 2")
# Out:
# b buyuk
# b buyuk
# c buyuk 2

# %%
x = 5
y = 4
z = 3

if x > y:
    if y > z:
        print("y buyuk z")
    print("x buyuk y")
# Out:
# y buyuk z
# x buyuk y

# %%
x = 5
y = 4
z = 3

if x > y > z:
    print("x en buyuk")
# Out:
# x en buyuk

# %%
x = 5
y = 4
z = 3

# iki koşulda doğru olmalı
if x > y and y > z:
    print("x en buyuk 2")
# Out:
# x en buyuk 2

# %%
x = 5
y = 4
z = 3

# iki koşuldan biri doğru olmalı
if x > y or y > z:
    print("x veya y en buyuk")
# Out:
# x veya y en buyuk

# %%
p = 3
k = 4
m = 5

print("p k'den büyük") if p > k else print("p k'den küçük")
# Out:
# p k'den küçük

# %%
isim1 = "Fatih"
isim2 = "fatih"

if isim1 == isim2:
    print("ayni isim")
else:
    print("ayni isim degil!")
# Out:
# ayni isim degil!

# %%
isim3 = "Fatih"
isim4 = "Fatih"

if isim3 == isim4:
    print("ayni isim")
else:
    print("ayni isim degil!")
# Out:
# ayni isim

# %%
isim5 = "Fatih"
isim6 = "Fatih Zor"

if isim5 in isim6:
    print("icinde")
else:
    print("icinde degil!")
# Out:
# icinde

# %%
isim5 = "Fatih"
isim6 = "Fatih Zor"

if "Ata" in isim6:
    print("icinde")
else:
    print("icinde degil!")
# Out:
# icinde degil!
